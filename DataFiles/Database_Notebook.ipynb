-- %% [markdown]
-- # [FoodDataCentral]

-- %%
USE [Technovity]
GO

-- %%
/****** Object:  Schema [FoodDataCentral]    Script Date: 4/29/2024 10:32:23 PM ******/
CREATE SCHEMA [FoodDataCentral]
GO

-- %% [markdown]
-- # [FoodDataCentral].[acquisition_samples]

-- %%
/****** Object:  Table [FoodDataCentral].[acquisition_samples]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[acquisition_samples](
	[fdc_id_of_sample_food] [int] NOT NULL,
	[fdc_id_of_acquisition_food] [int] NULL,
 CONSTRAINT [PK_acquisition_samples] PRIMARY KEY CLUSTERED 
(
	[fdc_id_of_sample_food] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[agricultural_samples]

-- %%
/****** Object:  Table [FoodDataCentral].[agricultural_samples]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[agricultural_samples](
	[fdc_id] [int] NOT NULL,
	[acquisition_date] [date] NULL,
	[market_class] [varchar](50) NULL,
	[treatment] [varchar](50) NULL,
	[state] [varchar](2) NULL,
 CONSTRAINT [PK_agricultural_samples] PRIMARY KEY CLUSTERED 
(
	[fdc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[branded_food]

-- %%
/****** Object:  Table [FoodDataCentral].[branded_food]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[branded_food](
	[fdc_id] [int] NOT NULL,
	[brand_owner] [varchar](255) NULL,
	[brand_name] [varchar](255) NULL,
	[subbrand_name] [varchar](255) NULL,
	[gtin_upc] [varchar](20) NULL,
	[ingredients] [varchar](max) NULL,
	[not_a_significant_source_of] [varchar](255) NULL,
	[serving_size] [int] NULL,
	[serving_size_unit] [varchar](50) NULL,
	[household_serving_fulltext] [varchar](255) NULL,
	[branded_food_category] [varchar](255) NULL,
	[data_source] [varchar](255) NULL,
	[package_weight] [int] NULL,
	[modified_date] [date] NULL,
	[available_date] [date] NULL,
	[market_country] [varchar](255) NULL,
	[discontinued_date] [date] NULL,
	[preparation_state_code] [varchar](10) NULL,
	[trade_channel] [varchar](255) NULL,
	[short_description] [varchar](255) NULL,
 CONSTRAINT [PK_branded_food] PRIMARY KEY CLUSTERED 
(
	[fdc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[fndds_derivation]

-- %%
/****** Object:  Table [FoodDataCentral].[fndds_derivation]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[fndds_derivation](
	[SR_28_derivation_code] [varchar](2) NOT NULL,
	[SR_28_derivation_description] [varchar](255) NULL,
 CONSTRAINT [PK_fndds_derivation] PRIMARY KEY CLUSTERED 
(
	[SR_28_derivation_code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[fndds_ingredient_nutrient_value]

-- %%
/****** Object:  Table [FoodDataCentral].[fndds_ingredient_nutrient_value]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[fndds_ingredient_nutrient_value](
	[ingredient_code] [varchar](10) NOT NULL,
	[ingredient_description] [varchar](255) NULL,
	[nutrient_code] [int] NULL,
	[nutrient_value] [decimal](18, 2) NULL,
	[nutrient_value_source] [varchar](50) NULL,
	[fdc_id] [int] NULL,
	[derivation_code] [varchar](10) NULL,
	[SR_AddMod_year] [int] NULL,
	[Foundation_year_acquired] [int] NULL,
	[Start_date] [date] NULL,
	[End_date] [date] NULL,
 CONSTRAINT [PK_fndds_ingredient_nutrient_value] PRIMARY KEY CLUSTERED 
(
	[ingredient_code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food]

-- %%
/****** Object:  Table [FoodDataCentral].[food]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food](
	[fdc_id] [int] NOT NULL,
	[data_type] [varchar](50) NULL,
	[description] [varchar](255) NULL,
	[food_category_id] [int] NULL,
	[publication_date] [date] NULL,
 CONSTRAINT [PK_food] PRIMARY KEY CLUSTERED 
(
	[fdc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_attribute]

-- %%
/****** Object:  Table [FoodDataCentral].[food_attribute]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_attribute](
	[id] [int] NOT NULL,
	[fdc_id] [int] NULL,
	[seq_num] [int] NULL,
	[food_attribute_type_id] [int] NULL,
	[name] [varchar](255) NULL,
	[value] [varchar](max) NULL,
 CONSTRAINT [PK_food_attribute] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_attribute_type]

-- %%
/****** Object:  Table [FoodDataCentral].[food_attribute_type]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_attribute_type](
	[id] [int] NOT NULL,
	[name] [varchar](255) NULL,
	[description] [varchar](max) NULL,
 CONSTRAINT [PK_food_attribute_type] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_calorie_conversion_factor]

-- %%
/****** Object:  Table [FoodDataCentral].[food_calorie_conversion_factor]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_calorie_conversion_factor](
	[food_nutrient_conversion_factor_id] [int] NOT NULL,
	[protein_value] [decimal](18, 2) NULL,
	[fat_value] [decimal](18, 2) NULL,
	[carbohydrate_value] [decimal](18, 2) NULL,
 CONSTRAINT [PK_food_calorie_conversion_factor] PRIMARY KEY CLUSTERED 
(
	[food_nutrient_conversion_factor_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_category]

-- %%
/****** Object:  Table [FoodDataCentral].[food_category]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_category](
	[id] [int] NOT NULL,
	[code] [varchar](10) NULL,
	[description] [varchar](255) NULL,
 CONSTRAINT [PK_food_category] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_component]

-- %%
/****** Object:  Table [FoodDataCentral].[food_component]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_component](
	[id] [int] NOT NULL,
	[fdc_id] [int] NULL,
	[name] [varchar](255) NULL,
	[pct_weight] [decimal](5, 2) NULL,
	[is_refuse] [varchar](1) NULL,
	[gram_weight] [decimal](5, 2) NULL,
	[data_points] [int] NULL,
	[min_year_acquired] [int] NULL,
 CONSTRAINT [PK_food_component] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_nutrient]

-- %%
/****** Object:  Table [FoodDataCentral].[food_nutrient]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_nutrient](
	[id] [int] NOT NULL,
	[fdc_id] [int] NULL,
	[nutrient_id] [int] NULL,
	[amount] [decimal](18, 2) NULL,
	[data_points] [int] NULL,
	[derivation_id] [int] NULL,
	[min] [decimal](18, 2) NULL,
	[max] [decimal](18, 2) NULL,
	[median] [decimal](18, 2) NULL,
	[loq] [decimal](18, 2) NULL,
	[footnote] [varchar](255) NULL,
	[min_year_acquired] [int] NULL,
	[percent_daily_value] [int] NULL,
 CONSTRAINT [PK_food_nutrient] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_nutrient_conversion_factor]

-- %%
/****** Object:  Table [FoodDataCentral].[food_nutrient_conversion_factor]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_nutrient_conversion_factor](
	[id] [int] NOT NULL,
	[fdc_id] [int] NULL,
 CONSTRAINT [PK_food_nutrient_conversion_factor] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_nutrient_derivation]

-- %%
/****** Object:  Table [FoodDataCentral].[food_nutrient_derivation]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_nutrient_derivation](
	[id] [int] NOT NULL,
	[code] [varchar](2) NULL,
	[description] [varchar](255) NULL,
 CONSTRAINT [PK_food_nutrient_derivation] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_nutrient_source]

-- %%
/****** Object:  Table [FoodDataCentral].[food_nutrient_source]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_nutrient_source](
	[id] [int] NOT NULL,
	[code] [varchar](2) NULL,
	[description] [varchar](255) NULL,
 CONSTRAINT [PK_food_nutrient_source] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_portion]

-- %%
/****** Object:  Table [FoodDataCentral].[food_portion]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_portion](
	[id] [int] NOT NULL,
	[fdc_id] [int] NULL,
	[seq_num] [int] NULL,
	[amount] [decimal](18, 2) NULL,
	[measure_unit_id] [int] NULL,
	[portion_description] [varchar](255) NULL,
	[modifier] [varchar](255) NULL,
	[gram_weight] [decimal](18, 2) NULL,
	[data_points] [int] NULL,
	[footnote] [varchar](255) NULL,
	[min_year_acquired] [int] NULL,
 CONSTRAINT [PK_food_portion] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_protein_conversion_factor]

-- %%
/****** Object:  Table [FoodDataCentral].[food_protein_conversion_factor]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_protein_conversion_factor](
	[food_nutrient_conversion_factor_id] [int] NOT NULL,
	[value] [decimal](18, 2) NULL,
 CONSTRAINT [PK_food_protein_conversion_factor] PRIMARY KEY CLUSTERED 
(
	[food_nutrient_conversion_factor_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[food_update_log_entry]

-- %%
/****** Object:  Table [FoodDataCentral].[food_update_log_entry]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[food_update_log_entry](
	[id] [int] NOT NULL,
	[description] [varchar](255) NULL,
	[last_updated] [date] NULL,
 CONSTRAINT [PK_food_update_log_entry] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[foundation_food]

-- %%
/****** Object:  Table [FoodDataCentral].[foundation_food]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[foundation_food](
	[fdc_id] [int] NOT NULL,
	[NDB_number] [int] NULL,
	[footnote] [varchar](255) NULL,
 CONSTRAINT [PK_foundation_food] PRIMARY KEY CLUSTERED 
(
	[fdc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[input_food]

-- %%
/****** Object:  Table [FoodDataCentral].[input_food]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[input_food](
	[id] [int] NOT NULL,
	[fdc_id] [int] NULL,
	[fdc_id_of_input_food] [int] NULL,
	[seq_num] [int] NULL,
	[amount] [decimal](18, 2) NULL,
	[sr_code] [int] NULL,
	[sr_description] [varchar](255) NULL,
	[unit] [varchar](10) NULL,
	[portion_code] [int] NULL,
	[portion_description] [varchar](255) NULL,
	[gram_weight] [decimal](18, 2) NULL,
	[retention_code] [int] NULL,
	[survey_flag] [int] NULL,
 CONSTRAINT [PK_input_food] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[lab_method]

-- %%
/****** Object:  Table [FoodDataCentral].[lab_method]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[lab_method](
	[id] [int] NOT NULL,
	[description] [varchar](255) NULL,
	[technique] [varchar](50) NULL,
 CONSTRAINT [PK_lab_method] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[lab_method_code]

-- %%
/****** Object:  Table [FoodDataCentral].[lab_method_code]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[lab_method_code](
	[lab_method_id] [int] NULL,
	[code] [varchar](20) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[lab_method_nutrient]

-- %%
/****** Object:  Table [FoodDataCentral].[lab_method_nutrient]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[lab_method_nutrient](
	[lab_method_id] [int] NULL,
	[nutrient_id] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[market_acquisition]

-- %%
/****** Object:  Table [FoodDataCentral].[market_acquisition]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[market_acquisition](
	[fdc_id] [int] NOT NULL,
	[brand_description] [varchar](255) NULL,
	[expiration_date] [date] NULL,
	[label_weight] [decimal](18, 9) NULL,
	[location] [varchar](255) NULL,
	[acquisition_date] [date] NULL,
	[sales_type] [varchar](10) NULL,
	[sample_lot_nbr] [varchar](50) NULL,
	[sell_by_date] [date] NULL,
	[store_city] [varchar](255) NULL,
	[store_name] [varchar](255) NULL,
	[store_state] [varchar](10) NULL,
	[upc_code] [varchar](50) NULL,
 CONSTRAINT [PK_market_acquisition] PRIMARY KEY CLUSTERED 
(
	[fdc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[measure_unit]

-- %%
/****** Object:  Table [FoodDataCentral].[measure_unit]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[measure_unit](
	[id] [int] NOT NULL,
	[name] [varchar](255) NULL,
 CONSTRAINT [PK_measure_unit] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[microbe]

-- %%
/****** Object:  Table [FoodDataCentral].[microbe]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[microbe](
	[id] [int] NOT NULL,
	[foodId] [int] NULL,
	[method] [varchar](255) NULL,
	[microbe_code] [varchar](255) NULL,
	[min_value] [int] NULL,
	[max_value] [int] NULL,
	[uom] [varchar](10) NULL,
 CONSTRAINT [PK_microbe] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[nutrient]

-- %%
/****** Object:  Table [FoodDataCentral].[nutrient]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[nutrient](
	[id] [int] NOT NULL,
	[name] [varchar](255) NULL,
	[unit_name] [varchar](255) NULL,
	[nutrient_nbr] [int] NULL,
	[rank] [int] NULL,
 CONSTRAINT [PK_nutrient] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[nutrient_incoming_name]

-- %%
/****** Object:  Table [FoodDataCentral].[nutrient_incoming_name]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[nutrient_incoming_name](
	[id] [int] NOT NULL,
	[name] [varchar](255) NULL,
	[nutrient_id] [int] NULL,
 CONSTRAINT [PK_nutrient_incoming_name] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[retention_factor]

-- %%
/****** Object:  Table [FoodDataCentral].[retention_factor]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[retention_factor](
	[n_gid] [int] NOT NULL,
	[n_code] [int] NULL,
	[n_foodGroupId] [int] NULL,
	[n_description] [varchar](255) NULL,
 CONSTRAINT [PK_retention_factor] PRIMARY KEY CLUSTERED 
(
	[n_gid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[sample_food]

-- %%
/****** Object:  Table [FoodDataCentral].[sample_food]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[sample_food](
	[fdc_id] [int] NOT NULL,
 CONSTRAINT [PK_sample_food] PRIMARY KEY CLUSTERED 
(
	[fdc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[sr_legacy_food]

-- %%
/****** Object:  Table [FoodDataCentral].[sr_legacy_food]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[sr_legacy_food](
	[fdc_id] [int] NOT NULL,
	[NDB_number] [int] NULL,
 CONSTRAINT [PK_sr_legacy_food] PRIMARY KEY CLUSTERED 
(
	[fdc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[sub_sample_food]

-- %%
/****** Object:  Table [FoodDataCentral].[sub_sample_food]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[sub_sample_food](
	[fdc_id] [int] NOT NULL,
	[fdc_id_of_sample_food] [int] NULL,
 CONSTRAINT [PK_sub_sample_food] PRIMARY KEY CLUSTERED 
(
	[fdc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[sub_sample_result]

-- %%
/****** Object:  Table [FoodDataCentral].[sub_sample_result]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[sub_sample_result](
	[food_nutrient_id] [int] NOT NULL,
	[adjusted_amount] [decimal](18, 2) NULL,
	[lab_method_id] [int] NULL,
	[nutrient_name] [varchar](255) NULL,
 CONSTRAINT [PK_sub_sample_result] PRIMARY KEY CLUSTERED 
(
	[food_nutrient_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[survey_fndds_food]

-- %%
/****** Object:  Table [FoodDataCentral].[survey_fndds_food]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[survey_fndds_food](
	[fdc_id] [int] NOT NULL,
	[food_code] [int] NULL,
	[wweia_category_code] [int] NULL,
	[start_date] [date] NULL,
	[end_date] [date] NULL,
 CONSTRAINT [PK_survey_fndds_food] PRIMARY KEY CLUSTERED 
(
	[fdc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FoodDataCentral].[wweia_food_category]

-- %%
/****** Object:  Table [FoodDataCentral].[wweia_food_category]    Script Date: 4/29/2024 10:32:23 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [FoodDataCentral].[wweia_food_category](
	[wweia_food_category] [int] NOT NULL,
	[wweia_food_category_description] [varchar](255) NULL,
 CONSTRAINT [PK_wweia_food_category] PRIMARY KEY CLUSTERED 
(
	[wweia_food_category] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_acquisition_samples_fdc_id_of_acquisition_food]

-- %%
ALTER TABLE [FoodDataCentral].[acquisition_samples]  WITH CHECK ADD  CONSTRAINT [FK_acquisition_samples_fdc_id_of_acquisition_food] FOREIGN KEY([fdc_id_of_acquisition_food])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[acquisition_samples] CHECK CONSTRAINT [FK_acquisition_samples_fdc_id_of_acquisition_food]
GO

-- %% [markdown]
-- # [FK_agricultural_samples_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[agricultural_samples]  WITH CHECK ADD  CONSTRAINT [FK_agricultural_samples_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[agricultural_samples] CHECK CONSTRAINT [FK_agricultural_samples_fdc_id]
GO

-- %% [markdown]
-- # [FK_food_attribute_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[food_attribute]  WITH CHECK ADD  CONSTRAINT [FK_food_attribute_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[food_attribute] CHECK CONSTRAINT [FK_food_attribute_fdc_id]
GO

-- %% [markdown]
-- # [FK_food_attribute_food_attribute_type_id]

-- %%
ALTER TABLE [FoodDataCentral].[food_attribute]  WITH CHECK ADD  CONSTRAINT [FK_food_attribute_food_attribute_type_id] FOREIGN KEY([food_attribute_type_id])
REFERENCES [FoodDataCentral].[food_attribute_type] ([id])
GO
ALTER TABLE [FoodDataCentral].[food_attribute] CHECK CONSTRAINT [FK_food_attribute_food_attribute_type_id]
GO

-- %% [markdown]
-- # [FK_food_calorie_conversion_factor_food_nutrient_conversion_factor_id]

-- %%
ALTER TABLE [FoodDataCentral].[food_calorie_conversion_factor]  WITH CHECK ADD  CONSTRAINT [FK_food_calorie_conversion_factor_food_nutrient_conversion_factor_id] FOREIGN KEY([food_nutrient_conversion_factor_id])
REFERENCES [FoodDataCentral].[food_nutrient_conversion_factor] ([id])
GO
ALTER TABLE [FoodDataCentral].[food_calorie_conversion_factor] CHECK CONSTRAINT [FK_food_calorie_conversion_factor_food_nutrient_conversion_factor_id]
GO

-- %% [markdown]
-- # [FK_food_component_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[food_component]  WITH CHECK ADD  CONSTRAINT [FK_food_component_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[food_component] CHECK CONSTRAINT [FK_food_component_fdc_id]
GO

-- %% [markdown]
-- # [FK_food_nutrient_derivation_id]

-- %%
ALTER TABLE [FoodDataCentral].[food_nutrient]  WITH CHECK ADD  CONSTRAINT [FK_food_nutrient_derivation_id] FOREIGN KEY([derivation_id])
REFERENCES [FoodDataCentral].[food_nutrient_derivation] ([id])
GO
ALTER TABLE [FoodDataCentral].[food_nutrient] CHECK CONSTRAINT [FK_food_nutrient_derivation_id]
GO

-- %% [markdown]
-- # [FK_food_nutrient_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[food_nutrient]  WITH CHECK ADD  CONSTRAINT [FK_food_nutrient_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[food_nutrient] CHECK CONSTRAINT [FK_food_nutrient_fdc_id]
GO

-- %% [markdown]
-- # [FK_food_nutrient_nutrient_id]

-- %%
ALTER TABLE [FoodDataCentral].[food_nutrient]  WITH CHECK ADD  CONSTRAINT [FK_food_nutrient_nutrient_id] FOREIGN KEY([nutrient_id])
REFERENCES [FoodDataCentral].[nutrient] ([id])
GO
ALTER TABLE [FoodDataCentral].[food_nutrient] CHECK CONSTRAINT [FK_food_nutrient_nutrient_id]
GO

-- %% [markdown]
-- # [FK_food_portion_measure_unit_id]

-- %%
ALTER TABLE [FoodDataCentral].[food_portion]  WITH CHECK ADD  CONSTRAINT [FK_food_portion_measure_unit_id] FOREIGN KEY([measure_unit_id])
REFERENCES [FoodDataCentral].[measure_unit] ([id])
GO
ALTER TABLE [FoodDataCentral].[food_portion] CHECK CONSTRAINT [FK_food_portion_measure_unit_id]
GO

-- %% [markdown]
-- # [FK_input_food_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[input_food]  WITH CHECK ADD  CONSTRAINT [FK_input_food_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[input_food] CHECK CONSTRAINT [FK_input_food_fdc_id]
GO

-- %% [markdown]
-- # [FK_input_food_fdc_id_of_input_food]

-- %%
ALTER TABLE [FoodDataCentral].[input_food]  WITH CHECK ADD  CONSTRAINT [FK_input_food_fdc_id_of_input_food] FOREIGN KEY([fdc_id_of_input_food])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[input_food] CHECK CONSTRAINT [FK_input_food_fdc_id_of_input_food]
GO

-- %% [markdown]
-- # [FK_lab_method_code_lab_method_id]

-- %%
ALTER TABLE [FoodDataCentral].[lab_method_code]  WITH CHECK ADD  CONSTRAINT [FK_lab_method_code_lab_method_id] FOREIGN KEY([lab_method_id])
REFERENCES [FoodDataCentral].[lab_method] ([id])
GO
ALTER TABLE [FoodDataCentral].[lab_method_code] CHECK CONSTRAINT [FK_lab_method_code_lab_method_id]
GO

-- %% [markdown]
-- # [FK_lab_method_nutrient_lab_method_id]

-- %%
ALTER TABLE [FoodDataCentral].[lab_method_nutrient]  WITH CHECK ADD  CONSTRAINT [FK_lab_method_nutrient_lab_method_id] FOREIGN KEY([lab_method_id])
REFERENCES [FoodDataCentral].[lab_method] ([id])
GO
ALTER TABLE [FoodDataCentral].[lab_method_nutrient] CHECK CONSTRAINT [FK_lab_method_nutrient_lab_method_id]
GO

-- %% [markdown]
-- # [FK_market_acquisition_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[market_acquisition]  WITH CHECK ADD  CONSTRAINT [FK_market_acquisition_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[market_acquisition] CHECK CONSTRAINT [FK_market_acquisition_fdc_id]
GO

-- %% [markdown]
-- # [FK_microbe_foodId]

-- %%
ALTER TABLE [FoodDataCentral].[microbe]  WITH CHECK ADD  CONSTRAINT [FK_microbe_foodId] FOREIGN KEY([foodId])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[microbe] CHECK CONSTRAINT [FK_microbe_foodId]
GO

-- %% [markdown]
-- # [FK_sample_food_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[sample_food]  WITH CHECK ADD  CONSTRAINT [FK_sample_food_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[sample_food] CHECK CONSTRAINT [FK_sample_food_fdc_id]
GO

-- %% [markdown]
-- # [FK_sr_legacy_food_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[sr_legacy_food]  WITH CHECK ADD  CONSTRAINT [FK_sr_legacy_food_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[sr_legacy_food] CHECK CONSTRAINT [FK_sr_legacy_food_fdc_id]
GO

-- %% [markdown]
-- # [FK_sub_sample_food_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[sub_sample_food]  WITH CHECK ADD  CONSTRAINT [FK_sub_sample_food_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[sub_sample_food] CHECK CONSTRAINT [FK_sub_sample_food_fdc_id]
GO

-- %% [markdown]
-- # [FK_sub_sample_food_fdc_id_of_sample_food]

-- %%
ALTER TABLE [FoodDataCentral].[sub_sample_food]  WITH CHECK ADD  CONSTRAINT [FK_sub_sample_food_fdc_id_of_sample_food] FOREIGN KEY([fdc_id_of_sample_food])
REFERENCES [FoodDataCentral].[sample_food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[sub_sample_food] CHECK CONSTRAINT [FK_sub_sample_food_fdc_id_of_sample_food]
GO

-- %% [markdown]
-- # [FK_sub_sample_result_food_nutrient_id]

-- %%
ALTER TABLE [FoodDataCentral].[sub_sample_result]  WITH CHECK ADD  CONSTRAINT [FK_sub_sample_result_food_nutrient_id] FOREIGN KEY([food_nutrient_id])
REFERENCES [FoodDataCentral].[food_nutrient] ([id])
GO
ALTER TABLE [FoodDataCentral].[sub_sample_result] CHECK CONSTRAINT [FK_sub_sample_result_food_nutrient_id]
GO

-- %% [markdown]
-- # [FK_sub_sample_result_lab_method_id]

-- %%
ALTER TABLE [FoodDataCentral].[sub_sample_result]  WITH CHECK ADD  CONSTRAINT [FK_sub_sample_result_lab_method_id] FOREIGN KEY([lab_method_id])
REFERENCES [FoodDataCentral].[lab_method] ([id])
GO
ALTER TABLE [FoodDataCentral].[sub_sample_result] CHECK CONSTRAINT [FK_sub_sample_result_lab_method_id]
GO

-- %% [markdown]
-- # [FK_survey_fndds_food_fdc_id]

-- %%
ALTER TABLE [FoodDataCentral].[survey_fndds_food]  WITH CHECK ADD  CONSTRAINT [FK_survey_fndds_food_fdc_id] FOREIGN KEY([fdc_id])
REFERENCES [FoodDataCentral].[food] ([fdc_id])
GO
ALTER TABLE [FoodDataCentral].[survey_fndds_food] CHECK CONSTRAINT [FK_survey_fndds_food_fdc_id]
GO

-- %% [markdown]
-- # [FK_survey_fndds_food_wweia_category_code]

-- %%
ALTER TABLE [FoodDataCentral].[survey_fndds_food]  WITH CHECK ADD  CONSTRAINT [FK_survey_fndds_food_wweia_category_code] FOREIGN KEY([wweia_category_code])
REFERENCES [FoodDataCentral].[wweia_food_category] ([wweia_food_category])
GO
ALTER TABLE [FoodDataCentral].[survey_fndds_food] CHECK CONSTRAINT [FK_survey_fndds_food_wweia_category_code]
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the sample food in the acquisition process.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'acquisition_samples', @level2type=N'COLUMN',@level2name=N'fdc_id_of_sample_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the acquisition food associated with the sample.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'acquisition_samples', @level2type=N'COLUMN',@level2name=N'fdc_id_of_acquisition_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Describes the samples acquired for analysis.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'acquisition_samples'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the agricultural sample.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'agricultural_samples', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Date when the sample was acquired.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'agricultural_samples', @level2type=N'COLUMN',@level2name=N'acquisition_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Market classification of the agricultural sample.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'agricultural_samples', @level2type=N'COLUMN',@level2name=N'market_class'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Treatment applied to the agricultural sample.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'agricultural_samples', @level2type=N'COLUMN',@level2name=N'treatment'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'State where the agricultural sample was collected.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'agricultural_samples', @level2type=N'COLUMN',@level2name=N'state'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Describes samples collected from agricultural sources.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'agricultural_samples'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the branded food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Owner of the brand for the food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'brand_owner'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Name of the brand for the food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'brand_name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Sub-brand name for the food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'subbrand_name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Global Trade Item Number (GTIN) or Universal Product Code (UPC) for the food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'gtin_upc'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Ingredients used in the food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'ingredients'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Indicates if the food product is not a significant source of a particular nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'not_a_significant_source_of'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Serving size of the food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'serving_size'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unit of measurement for the serving size of the food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'serving_size_unit'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the household serving size for the food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'household_serving_fulltext'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Category of the branded food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'branded_food_category'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Data source for information about the branded food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'data_source'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Weight of the package containing the branded food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'package_weight'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Date when the branded food product was last modified.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'modified_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Date when the branded food product became available.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'available_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Country where the branded food product is marketed.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'market_country'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Date when the branded food product was discontinued.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'discontinued_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code indicating the preparation state of the branded food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'preparation_state_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Trade channel through which the branded food product is distributed.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'trade_channel'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Short description of the branded food product.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food', @level2type=N'COLUMN',@level2name=N'short_description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Describes branded food products.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'branded_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code for the SR-28 derivation.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_derivation', @level2type=N'COLUMN',@level2name=N'SR_28_derivation_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description for the SR-28 derivation.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_derivation', @level2type=N'COLUMN',@level2name=N'SR_28_derivation_description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Describes derivations for SR-28 data.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_derivation'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code for the ingredient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'ingredient_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description for the ingredient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'ingredient_description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code for the nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'nutrient_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Value of the nutrient in the ingredient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'nutrient_value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Source of the nutrient value.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'nutrient_value_source'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key to link to FDC.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code for the derivation.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'derivation_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Year of addition or modification for SR data.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'SR_AddMod_year'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Year when foundation data was acquired.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'Foundation_year_acquired'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Start date of data relevance.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'Start_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'End date of data relevance.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value', @level2type=N'COLUMN',@level2name=N'End_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores nutrient values for ingredients in FNDDS.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'fndds_ingredient_nutrient_value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Type of data for the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food', @level2type=N'COLUMN',@level2name=N'data_type'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food', @level2type=N'COLUMN',@level2name=N'description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key to link to food categories.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food', @level2type=N'COLUMN',@level2name=N'food_category_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Date of publication for the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food', @level2type=N'COLUMN',@level2name=N'publication_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores information about food items in the database.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the food attribute.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key to link to food items.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Sequential number for the food attribute.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute', @level2type=N'COLUMN',@level2name=N'seq_num'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key to link to food attribute types.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute', @level2type=N'COLUMN',@level2name=N'food_attribute_type_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Name of the food attribute.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute', @level2type=N'COLUMN',@level2name=N'name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Value of the food attribute.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute', @level2type=N'COLUMN',@level2name=N'value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores attributes related to food items in the database.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the food attribute type.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute_type', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Name of the food attribute type.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute_type', @level2type=N'COLUMN',@level2name=N'name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the food attribute type.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute_type', @level2type=N'COLUMN',@level2name=N'description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores types of attributes related to food items in the database.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_attribute_type'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the calorie conversion factor.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_calorie_conversion_factor', @level2type=N'COLUMN',@level2name=N'food_nutrient_conversion_factor_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Calorie conversion factor for protein.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_calorie_conversion_factor', @level2type=N'COLUMN',@level2name=N'protein_value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Calorie conversion factor for fat.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_calorie_conversion_factor', @level2type=N'COLUMN',@level2name=N'fat_value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Calorie conversion factor for carbohydrates.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_calorie_conversion_factor', @level2type=N'COLUMN',@level2name=N'carbohydrate_value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores calorie conversion factors for different nutrients in food items.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_calorie_conversion_factor'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the food category.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_category', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code representing the food category.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_category', @level2type=N'COLUMN',@level2name=N'code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the food category.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_category', @level2type=N'COLUMN',@level2name=N'description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores information about different categories of food items.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_category'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the food component.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_component', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key referencing the FDC ID of the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_component', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Name of the food component.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_component', @level2type=N'COLUMN',@level2name=N'name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Percentage weight of the food component.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_component', @level2type=N'COLUMN',@level2name=N'pct_weight'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Flag indicating if the food component is refuse.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_component', @level2type=N'COLUMN',@level2name=N'is_refuse'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Gram weight of the food component.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_component', @level2type=N'COLUMN',@level2name=N'gram_weight'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Number of data points for the food component.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_component', @level2type=N'COLUMN',@level2name=N'data_points'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Minimum year when the food component was acquired.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_component', @level2type=N'COLUMN',@level2name=N'min_year_acquired'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores information about components of food items.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_component'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the food nutrient record.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key referencing the FDC ID of the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'nutrient_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Amount of the nutrient in the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'amount'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Number of data points for the nutrient in the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'data_points'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the derivation of the nutrient value.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'derivation_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Minimum value of the nutrient in the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'min'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Maximum value of the nutrient in the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'max'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Median value of the nutrient in the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'median'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Limit of quantitation for the nutrient in the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'loq'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Footnote for the nutrient in the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'footnote'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Minimum year when the nutrient data was acquired.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'min_year_acquired'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Percent daily value of the nutrient in the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient', @level2type=N'COLUMN',@level2name=N'percent_daily_value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores information about nutrients in food items.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the conversion factor record.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_conversion_factor', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key referencing the FDC ID of the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_conversion_factor', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores conversion factors for nutrients in food items.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_conversion_factor'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the derivation record.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_derivation', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code representing the derivation.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_derivation', @level2type=N'COLUMN',@level2name=N'code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the derivation.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_derivation', @level2type=N'COLUMN',@level2name=N'description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores derivations for food nutrient values.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_derivation'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the nutrient source.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_source', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code representing the nutrient source.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_source', @level2type=N'COLUMN',@level2name=N'code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the nutrient source.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_source', @level2type=N'COLUMN',@level2name=N'description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores sources of food nutrient data.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_nutrient_source'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the food portion.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key to link to the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Sequence number for the food portion.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'seq_num'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Amount of the food portion.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'amount'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the measure unit of the portion.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'measure_unit_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the food portion.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'portion_description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Modifier for the food portion.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'modifier'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Weight of the food portion in grams.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'gram_weight'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Number of data points for the food portion.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'data_points'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Footnote for the food portion.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'footnote'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Minimum year when the portion was acquired.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion', @level2type=N'COLUMN',@level2name=N'min_year_acquired'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores information about food portions.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_portion'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key to link to the food nutrient conversion factor.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_protein_conversion_factor', @level2type=N'COLUMN',@level2name=N'food_nutrient_conversion_factor_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Protein conversion factor value.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_protein_conversion_factor', @level2type=N'COLUMN',@level2name=N'value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores protein conversion factors for food items.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_protein_conversion_factor'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the update.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_update_log_entry', @level2type=N'COLUMN',@level2name=N'description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Date when the update was last performed.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_update_log_entry', @level2type=N'COLUMN',@level2name=N'last_updated'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Keeps track of updates made to food data entries.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'food_update_log_entry'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Nutrient Database Number identifying the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'foundation_food', @level2type=N'COLUMN',@level2name=N'NDB_number'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Additional notes or comments about the food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'foundation_food', @level2type=N'COLUMN',@level2name=N'footnote'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores foundation food data including FDC ID, NDB number, and footnotes.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'foundation_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key referencing the FDC ID of the input food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key referencing the FDC ID of the input food item being measured.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'fdc_id_of_input_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Sequence number indicating the order of input for a food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'seq_num'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Amount of the input food item in the specified unit.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'amount'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'SR code indicating the food item from the Standard Reference database.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'sr_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the food item from the Standard Reference database.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'sr_description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unit of measurement for the amount of the input food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'unit'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code indicating the portion size of the input food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'portion_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the portion size of the input food item.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'portion_description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Weight of the input food item in grams.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'gram_weight'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code indicating the retention factor for nutrient calculation.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'retention_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Flag indicating if the food item was part of a survey.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food', @level2type=N'COLUMN',@level2name=N'survey_flag'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores input food data including FDC ID, sequence number, amount, SR code, and survey flags.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'input_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the lab method.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the lab method.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method', @level2type=N'COLUMN',@level2name=N'description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Technique used in the lab method.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method', @level2type=N'COLUMN',@level2name=N'technique'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores information about lab methods including ID, description, and technique.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key referencing the lab_method table.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method_code', @level2type=N'COLUMN',@level2name=N'lab_method_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code associated with the lab method.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method_code', @level2type=N'COLUMN',@level2name=N'code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores codes related to lab methods including ID and code.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key referencing the lab_method table.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method_nutrient', @level2type=N'COLUMN',@level2name=N'lab_method_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key referencing the nutrient table.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method_nutrient', @level2type=N'COLUMN',@level2name=N'nutrient_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores the relationship between lab methods and nutrients.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'lab_method_nutrient'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Primary key for the market_acquisition table.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the brand.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'brand_description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Date when the acquisition expires.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'expiration_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Weight of the label.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'label_weight'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Location of the market acquisition.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'location'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Date of the market acquisition.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'acquisition_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Type of sales for the market acquisition.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'sales_type'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Lot number of the sample.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'sample_lot_nbr'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Date by which the item needs to be sold.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'sell_by_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'City where the store is located.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'store_city'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Name of the store.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'store_name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'State where the store is located.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'store_state'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Universal Product Code.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition', @level2type=N'COLUMN',@level2name=N'upc_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Stores information about market acquisitions.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'market_acquisition'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the measure unit.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'measure_unit', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Name of the measure unit.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'measure_unit', @level2type=N'COLUMN',@level2name=N'name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing information about measure units.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'measure_unit'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the microbe.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'microbe', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the food associated with the microbe.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'microbe', @level2type=N'COLUMN',@level2name=N'foodId'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Method used for microbe analysis.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'microbe', @level2type=N'COLUMN',@level2name=N'method'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code representing the microbe.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'microbe', @level2type=N'COLUMN',@level2name=N'microbe_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Minimum value for the microbe.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'microbe', @level2type=N'COLUMN',@level2name=N'min_value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Maximum value for the microbe.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'microbe', @level2type=N'COLUMN',@level2name=N'max_value'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unit of measurement for the microbe values.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'microbe', @level2type=N'COLUMN',@level2name=N'uom'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing information about microbes.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'microbe'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Name of the nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient', @level2type=N'COLUMN',@level2name=N'name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unit name for the nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient', @level2type=N'COLUMN',@level2name=N'unit_name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Nutrient number.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient', @level2type=N'COLUMN',@level2name=N'nutrient_nbr'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Rank of the nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient', @level2type=N'COLUMN',@level2name=N'rank'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing information about nutrients.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Unique identifier for the incoming nutrient name.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient_incoming_name', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Name of the incoming nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient_incoming_name', @level2type=N'COLUMN',@level2name=N'name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Foreign key referencing the nutrient table.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient_incoming_name', @level2type=N'COLUMN',@level2name=N'nutrient_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing incoming names for nutrients.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'nutrient_incoming_name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the retention factor.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'retention_factor', @level2type=N'COLUMN',@level2name=N'n_gid'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code for the retention factor.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'retention_factor', @level2type=N'COLUMN',@level2name=N'n_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the food group associated with the retention factor.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'retention_factor', @level2type=N'COLUMN',@level2name=N'n_foodGroupId'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the retention factor.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'retention_factor', @level2type=N'COLUMN',@level2name=N'n_description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing retention factors for nutrients.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'retention_factor'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the sample food.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sample_food', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing sample foods.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sample_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the legacy food.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sr_legacy_food', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'NDB number for the legacy food.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sr_legacy_food', @level2type=N'COLUMN',@level2name=N'NDB_number'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing legacy foods.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sr_legacy_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the sub-sample food.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sub_sample_food', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the parent sample food.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sub_sample_food', @level2type=N'COLUMN',@level2name=N'fdc_id_of_sample_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing sub-samples of foods.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sub_sample_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the food nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sub_sample_result', @level2type=N'COLUMN',@level2name=N'food_nutrient_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Adjusted amount for the nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sub_sample_result', @level2type=N'COLUMN',@level2name=N'adjusted_amount'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the laboratory method.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sub_sample_result', @level2type=N'COLUMN',@level2name=N'lab_method_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Name of the nutrient.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sub_sample_result', @level2type=N'COLUMN',@level2name=N'nutrient_name'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing results of sub-samples for nutrients.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'sub_sample_result'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the Fndds food.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'survey_fndds_food', @level2type=N'COLUMN',@level2name=N'fdc_id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code for the Fndds food.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'survey_fndds_food', @level2type=N'COLUMN',@level2name=N'food_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Code for the WWEIA food category.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'survey_fndds_food', @level2type=N'COLUMN',@level2name=N'wweia_category_code'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Start date for the survey data.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'survey_fndds_food', @level2type=N'COLUMN',@level2name=N'start_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'End date for the survey data.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'survey_fndds_food', @level2type=N'COLUMN',@level2name=N'end_date'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing survey data for Fndds food.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'survey_fndds_food'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Identifier for the WWEIA food category.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'wweia_food_category', @level2type=N'COLUMN',@level2name=N'wweia_food_category'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Description of the WWEIA food category.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'wweia_food_category', @level2type=N'COLUMN',@level2name=N'wweia_food_category_description'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'Table containing WWEIA food categories.' , @level0type=N'SCHEMA',@level0name=N'FoodDataCentral', @level1type=N'TABLE',@level1name=N'wweia_food_category'
GO
